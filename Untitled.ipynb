# %%
pip3 install dotenv
# Out:
#   Cell In[2], line 1
#     pip3 install dotenv
#          ^
# SyntaxError: invalid syntax

# %%
import psycopg2 as pg
from dotenv import load_dotenv
import os
import pandas as pd

# Load environment variables from the .env file
load_dotenv()

# Access the variables
db_name = os.getenv("DB_NAME")
db_user = os.getenv("DB_USER")
db_password = os.getenv("DB_PASSWORD")
db_host = os.getenv("DB_HOST")
db_port = os.getenv("DB_PORT")

conn = pg.connect(
    dbname=db_name,
    user=db_user,
    password=db_password,
    host=db_host,
    port=db_port
)

cur = conn.cursor()
cur.execute("""COPY(SELECT q.text,q.difficulty,c.* FROM andrewslearningapi_question AS q JOIN 
            andrewslearningapi_course as c ON q.course_id=c.id WHERE c.name='Organic Chemistry' LIMIT 20)
            TO '/home/ab/test.csv'
            WITH CSV HEADER;""")
# Out:
# ---------------------------------------------------------------------------
# InsufficientPrivilege                     Traceback (most recent call last)
# Cell In[45], line 25
#      16 conn = pg.connect(
#      17     dbname=db_name,
#      18     user=db_user,
#    (...)
#      21     port=db_port
#      22 )
#      24 cur = conn.cursor()
# ---> 25 cur.execute("""COPY(SELECT q.text,q.difficulty,c.* FROM andrewslearningapi_question AS q JOIN
#      26             andrewslearningapi_course as c ON q.course_id=c.id WHERE c.name='Organic Chemistry' LIMIT 20)
#      27             TO '/home/ab/test.csv'
#      28             WITH CSV HEADER;""")
#
# InsufficientPrivilege: could not open file "/home/ab/test.csv" for writing: Permission denied
# HINT:  COPY TO instructs the PostgreSQL server process to write a file. You may want a client-side facility such as psql's \copy.

# %%
df
# Out:
#                                                     0     1  2  \
# 0                                            Testing   0.50  8
# 1                                             asdfadf  0.50  8
# 2                                               Test3  0.50  8
# 3   What is the correct Lewis dot structure for ca...  0.50  8
# 4           What is the IUPAC name for this compound?  0.40  8
# 5           What is the IUPAC name for this compound?  0.50  8
# 6   Which of the following is a correct name for (...  0.40  8
# 7     Which of the following is 3,3-diphenylpropanal?  0.50  8
# 8   Which of the following compounds is not named ...  0.60  8
# 9   Which of the following reaction sequences woul...  0.60  8
# 10  Which of the following Wittig reagents would b...  0.70  8
# 11  Two equivalents of the Wittig reagent (CH3)2C=...  0.80  8
# 12  The Wittig reaction takes place between a carb...  0.70  8
# 13        What is the major product of this reaction?  0.60  8
# 14        What is the major product of this reaction?  0.60  8
# 15          What is the IUPAC name for this compound?  0.40  8
# 16  What is the correct Lewis dot structure for ca...  0.50  8
# 17          What is the IUPAC name for this compound?  2.00  8
# 18          What is the IUPAC name for this compound?  0.55  8
# 19          What is the IUPAC name for this compound?  2.50  8
#
#                     3 4 5     6      7     8
# 0   Organic Chemistry      None  False  True
# 1   Organic Chemistry      None  False  True
# 2   Organic Chemistry      None  False  True
# 3   Organic Chemistry      None  False  True
# 4   Organic Chemistry      None  False  True
# 5   Organic Chemistry      None  False  True
# 6   Organic Chemistry      None  False  True
# 7   Organic Chemistry      None  False  True
# 8   Organic Chemistry      None  False  True
# 9   Organic Chemistry      None  False  True
# 10  Organic Chemistry      None  False  True
# 11  Organic Chemistry      None  False  True
# 12  Organic Chemistry      None  False  True
# 13  Organic Chemistry      None  False  True
# 14  Organic Chemistry      None  False  True
# 15  Organic Chemistry      None  False  True
# 16  Organic Chemistry      None  False  True
# 17  Organic Chemistry      None  False  True
# 18  Organic Chemistry      None  False  True
# 19  Organic Chemistry      None  False  True

# %%
print(courses)
# Out:
# None
